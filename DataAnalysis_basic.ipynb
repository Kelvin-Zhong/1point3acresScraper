# %%
# %run FileManager.ipynb
# %run DataAnalysisHelper.ipynb
file_manager = FileManager()
posts_data = file_manager.readFromFile('posts_data')
data_helper = DataAnalysisHelper()

# %%
target_female, target_male = data_helper.bisectCommentsForPostData(posts_data, 'isTargetedFemale')
# bucket_names, bucket_values = data_helper.bucketize(0, 50, 5, target_female)
# data_helper.drawBarChart(bucket_names, bucket_values)
# data_helper.drawPieChart(bucket_names, bucket_values)
# print(data_helper.getListStatistics(bucket_values))

# bucket_names, bucket_values = data_helper.bucketize(0, 50, 5, target_male)
# data_helper.drawBarChart(bucket_names, bucket_values)
# data_helper.drawPieChart(bucket_names, bucket_values)
# print(data_helper.getListStatistics(bucket_values))
bucket_names, bucket_values = data_helper.bucketize(0, 50, 5, target_female)
data_helper.printAllStats(bucket_names, bucket_values)

bucket_names, bucket_values = data_helper.bucketize(0, 50, 5, target_male)
data_helper.printAllStats(bucket_names, bucket_values)
# Out:
# {'mean': 16.666666666666668, 'median': 15.5}
# {'mean': 19.333333333333332, 'median': 22.0}

# %%
target_female, target_male = data_helper.bisectCommentsForPostData(posts_data, 'hasEmailInText')
print(len(target_female), len(target_male))
bucket_names, bucket_values = data_helper.bucketize(0, 50, 5, target_female)
data_helper.printAllStats(bucket_names, bucket_values)
bucket_names, bucket_values = data_helper.bucketize(0, 50, 5, target_male)
data_helper.printAllStats(bucket_names, bucket_values)
# Out:
# 85 131
# {'mean': 14.166666666666666, 'median': 12.0}
# {'mean': 21.833333333333332, 'median': 24.5}

# %%
target_female, target_male = data_helper.bisectCommentsForPostData(posts_data, 'hasLongText')
print(len(target_female), len(target_male))
bucket_names, bucket_values = data_helper.bucketize(0, 50, 5, target_female)
data_helper.printAllStats(bucket_names, bucket_values)
bucket_names, bucket_values = data_helper.bucketize(0, 50, 5, target_male)
data_helper.printAllStats(bucket_names, bucket_values)
# Out:
# 119 97
# {'mean': 19.833333333333332, 'median': 22.0}
# {'mean': 16.166666666666668, 'median': 12.5}

# %%
target_female, target_male = data_helper.bisectCommentsForPostData(posts_data, 'hasLongText')
print(len(target_female), len(target_male))
bucket_names, bucket_values = data_helper.bucketize(0, 50, 5, target_female)
data_helper.printAllStats(bucket_names, bucket_values)
bucket_names, bucket_values = data_helper.bucketize(0, 50, 5, target_male)
data_helper.printAllStats(bucket_names, bucket_values)

# %%
posts_data[0]
# Out:
# {'location': ' Bay Area',
# ...
